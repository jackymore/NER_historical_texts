# %% [markdown]
# # NER with spaCy

# %%
import spacy
from spacy import displacy
import spacytei
from bs4 import BeautifulSoup
import codecs
import de_core_news_lg
import pandas as pd
import numpy as np

# %% [markdown]
# ## Workflow
#
# ### 1. Parsing the XML file

# %%
#open document and use beautiful soup for parsing the xml file
with codecs.open("data/testdata/testdata.xml", "r", "utf-8") as file:
    soup = BeautifulSoup(file, "xml")

# %%
#using the text inside the element body
text = soup.body.get_text()

# %% [markdown]
# ### 2. Using a german standard Model

# %%
#loading standard nlp model for spacy
nlp = spacy.load("de_core_news_sm")
nlp = spacy.load("training_custom_model_with_spacy/custom_model")
doc = nlp(text)

# %% [markdown]
# ### 3. Printing all found Named Entities

# %%
data = []
for ent in doc.ents:
    data.append([ent.text, ent.label_])
df = pd.DataFrame(data, columns=['Entity', 'Label'])
df
# Out:
#                       Entity Label
# 0                    Stiebar   PER
# 1                       Wien   LOC
# 2                    Leopold   PER
# 3                    Metzger   PER
# 4                   Metzburg   PER
# 5                   Iohannes   PER
# 6                   Georgius   PER
# 7                    Mezburg   PER
# 8                     Johann   PER
# 9                      Georg   PER
# 10                  Metzburg   PER
# 11                  Metzburg   PER
# 12    Niederösterreichischer   PER
# 13          bankodeputazions   PER
# 14                         D   PER
# 15                        IV   PER
# 16                     Georg   PER
# 17                    Mezger   PER
# 18                   Scydack   PER
# 19                  Tschenzi   PER
# 20                    Meiran   PER
# 21                      Nota   PER
# 22                     Georg   PER
# 23                   Metzger   PER
# 24                  Freyburg   LOC
# 25                         +   PER
# 26                     Georg   PER
# 27                   Metzger   PER
# 28                  Freyburg   LOC
# 29                         +   PER
# ...                      ...   ...
# 2578                       d   PER
# 2579                   Spahi   PER
# 2580                 Lagnizi   PER
# 2581                   Tobzi   PER
# 2582                  Gebezi   PER
# 2583                  Serdey   PER
# 2584              Serdengezi   PER
# 2585                 Lagnezi   PER
# 2586                    Gehe   PER
# 2587                     Waß   PER
# 2588                    nilo   PER
# 2589                      Wo   PER
# 2590                    Alla   PER
# 2591                   rasos   PER
# 2592                  heffda   PER
# 2593                  Wilstu   PER
# 2594                      Iß   PER
# 2595                    Haar   PER
# 2596                 zanunda   PER
# 2597                    Dali   PER
# 2598                     Waß   PER
# 2599                 iocarda   PER
# 2600                    adam   PER
# 2601                    Prae   PER
# 2602                    Alla   PER
# 2603                   benum   PER
# 2604                 camerad   PER
# 2605                   iusel   PER
# 2606                    Hepp   PER
# 2607                  Ungarn   PER
#
# [2608 rows x 2 columns]

# %%
#counting entities
ent_anzahl = len(df)
print("Anzahl der gefundenen Entitäten:", ent_anzahl)
# Out:
# Anzahl der gefundenen Entitäten: 2608

# %%
df_20 = df.head(20) #show only first 20 entities
df_20
# Out:
#                     Entity Label
# 0                  Stiebar   PER
# 1                     Wien   LOC
# 2                  Leopold   PER
# 3                  Metzger   PER
# 4                 Metzburg   PER
# 5                 Iohannes   PER
# 6                 Georgius   PER
# 7                  Mezburg   PER
# 8                   Johann   PER
# 9                    Georg   PER
# 10                Metzburg   PER
# 11                Metzburg   PER
# 12  Niederösterreichischer   PER
# 13        bankodeputazions   PER
# 14                       D   PER
# 15                      IV   PER
# 16                   Georg   PER
# 17                  Mezger   PER
# 18                 Scydack   PER
# 19                Tschenzi   PER

# %%
displacy.render(doc, style="ent")
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr"></br></br></br></br> Wieder zurückerhalten aus der bibliothek des</br>                    herren kreishauptmanns, freyherrn von
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Stiebar
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  zu</br>                        Kröllendorf - in
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Wien
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  den 14. Novembris 1823. </br>                    Iohann
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Leopold
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Metzger
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  freyherr von
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Metzburg
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
# , kaiserlich-königlicher hofrath, </br></br></br>
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Iohannes
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Georgius
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  von</br>
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Mezburg
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
# .</br>Wappen des
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Johann
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Georg
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  von
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Metzburg
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
# . Es handelt sich um eine</br>                            später eingefügte Version des Wappens, denn erst ab 1690 durfte sich das Geschlecht von
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Metzburg
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
# </br>                            nennen.</br></br></br>
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Niederösterreichischer
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  regierungs-, auch</br>
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     bankodeputazions
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  rath, nieder- und oberösterreichischer landtstand 1718. </br></br></br></br>
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     D
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     IV
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  1</br></br></br>Iohann
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Georg
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Mezger
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  von Breysgaw</br></br></br></br>
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Scydack
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
# : ein kocher luck: ein bogen
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Tschenzi
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
# : ein seiten</br>
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Meiran
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
# : handtheben miten am bogen.</br>
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Nota
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; te
