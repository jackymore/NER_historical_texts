# %%
import nltk
from bs4 import BeautifulSoup
import codecs
from HanTa import HanoverTagger as ht

# %%
#open document and use beautiful soup for parsing the xml file

with codecs.open("data/TEI/Reisebericht_testdata.xml", "r", "utf-8") as file:
    soup = BeautifulSoup(file, "xml")

# %%
#using the text inside the element body
text = soup.body.get_text()
sentences = nltk.sent_tokenize(text, language='german')
print(sentences)
# Out:
# ['\n\n\n\n Wieder zurückerhalten aus der bibliothek des\n                    herren kreishauptmanns, freyherrn von Stiebar zu\n                        Kröllendorf - in Wien den 14.', 'Novembris 1823.', 'Iohann Leopold Metzger freyherr von Metzburg, kaiserlich-königlicher hofrath, \n\n\nIohannes Georgius von\n                            Mezburg.', 'Wappen des Johann Georg von Metzburg.', 'Es handelt sich um eine\n                            später eingefügte Version des Wappens, denn erst ab 1690 durfte sich das Geschlecht von Metzburg\n                            nennen.', 'Niederösterreichischer regierungs-, auch\n                    bankodeputazions rath, nieder- und oberösterreichischer landtstand 1718.', 'D IV 1\n\n\nIohann Georg Mezger von Breysgaw\n\n\n\nScydack: ein kocher luck: ein bogen Tschenzi: ein seiten\n                    Meiran: handtheben miten am bogen.', 'Nota bene\n\n\n\n\n\n\n\n1.', 'Iohann Georg von Metzger,\n                            patrizier in Freyburg.', '1615\n+\n2.', 'Iohann Georg von Metzger, regiments rath\n                                in Freyburg.', '1631\n+\n3.', 'Iohann Georg von Metzger,\n                            legationes sekretär in Constantinopel,\n                            von kaiser Leopold I. mit rath und bild\n                            beschenkt.', '4.', 'Iohann Georg Metzger von\n                                Metzburg, schreibt 1650 seine\n                            reise nach Constantinopel; postmaister\n                            und stadthauptmann in Brunn\n1697.', '5.', 'Carl Ioseph freyherr von Metzburg,\n                                1714.', '6.', 'Christoph Augustin freyherr von\n                                Metzburg, landrechtssekretär in Gratz, 1735.', '7.', 'Franz Leopold freyherr von\n                                Metzburg, chargé d`affaires in Neapel, Koppenhagen,\n                                Dresden, +\n1789.', '8.', 'Iohann Leopold Metzger freyherr von\n                                Metzburg, kaiserlich königlicher hofrath 1815, vizepräsident des general rechnungs direktoriums;\n                                2.', 'Iaenner 1828.', '9.', 'Heinrich Metzger freyherr von\n                                Metzburg, unterlieutenant bey prinz Friedrich von Sachsen cuirassiers, 1.', 'Octobris 1827.', '4.', 'Diplom kaiser Leopold I. vom 11.', 'Maii 1690.', '8.', 'Diplom kaiser Carl VI.', 'vom 24.', 'Dezembris 1714.', 'Turcicium Imperium.', 'Türckische Reych.', 'Concordia res parvae crescunt, discordia\n                                maximae dilabuntur.', 'Eingelegte, zeitgenössische Landkarte (Teile Süd- und Osteuropas,\n                            vorderer Orient, Teile Nordafrikas, Arabien).', 'Itinerarium oder rayß beschreibung von Wien in Österreich\n                    nach Constantinopel.', 'Darin werden beschriben die durchgerayste länder, stätt, vestungen, schlößer,\n                    märck unnd dörffer unnd deren inwohnenden völckher, arth unnd tracht, auch die\n                    audientzen, visitationes der pottschafter sambt anderen vihlen denckhwürdigen\n                    sachen.', 'In drey underschidliche thail außgethailt unnd mit etlichen abgerißnen figuren\n                    geziert.', 'Beschriben und zusammengetragen durch\nIohann Georg Metzger von Breysach auß\n                        dem Breyßgau, iuris utriusque studiosum, anno salutis\n1650 etc.\n\n\n\nVorrede ahn den guetherzigen leßer\nEß trinckhet die studierende iugendt dißen bekhandten schual versicul gleichsam mit ihrer muedtermilch ein:\n\n\nNon cuivis homini contingit adire Corinthum.', 'Daß ist: Nicht iedem widerfahrt die gnad, Corinthum zu beschauen die stadt.', 'Weilen nunmehr welt khündig, das die iugendt neues zuesagen oder zuhören, vilmehr\n                    aber zusehen ganz begirig ist, unnd etliche gleichsam von der natur in fern\n                    gelegne provinzen unnd länder zureißen angetriben werden.', 'Iedoch thuet solcher\n                     ...

# %%
tokenized_sent = nltk.tokenize.word_tokenize(sentences[2], language='german')
print(tokenized_sent)
# Out:
# ['Iohann', 'Leopold', 'Metzger', 'freyherr', 'von', 'Metzburg', ',', 'kaiserlich-königlicher', 'hofrath', ',', 'Iohannes', 'Georgius', 'von', 'Mezburg', '.']

# %%
tagger = ht.HanoverTagger('morphmodel_ger.pgz')

# %%
print(tagger.analyze('Johann'))
# Out:
# ('Johann', 'NE')

# %%
tags = tagger.tag_sent(tokenized_sent)

# %%
print(tags)
# Out:
# [('Iohann', 'Iohann', 'NE'), ('Leopold', 'Leopold', 'NE'), ('Metzger', 'Metzger', 'NE'), ('freyherr', 'freyherr', 'ADJD'), ('von', 'von', 'APPR'), ('Metzburg', 'Metzburg', 'NE'), (',', '--', '$,'), ('kaiserlich-königlicher', 'kaiserlich-königlich', 'ADJA'), ('hofrath', 'Hofrath', 'NE'), (',', '--', '$,'), ('Iohannes', 'Iohannes', 'NE'), ('Georgius', 'Georgius', 'NE'), ('von', 'von', 'APPR'), ('Mezburg', 'Mezburg', 'NE'), ('.', '--', '$.')]

# %%
tagged = nltk.pos_tag(tokenized_sent)
tagged[0:50]
# Out:
# [('Iohann', 'NNP'),
#  ('Leopold', 'NNP'),
#  ('Metzger', 'NNP'),
#  ('freyherr', 'VBD'),
#  ('von', 'NNP'),
#  ('Metzburg', 'NNP'),
#  (',', ','),
#  ('kaiserlich-königlicher', 'JJ'),
#  ('hofrath', 'NN'),
#  (',', ','),
#  ('Iohannes', 'NNP'),
#  ('Georgius', 'NNP'),
#  ('von', 'NNP'),
#  ('Mezburg', 'NNP'),
#  ('.', '.')]

# %%
entities = nltk.chunk.ne_chunk(tagged)
print(entities)
# Out:
# (S
#   (PERSON Iohann/NNP)
#   (PERSON Leopold/NNP Metzger/NNP)
#   freyherr/VBD
#   von/NNP
#   Metzburg/NNP
#   ,/,
#   kaiserlich-königlicher/JJ
#   hofrath/NN
#   ,/,
#   (PERSON Iohannes/NNP Georgius/NNP)
#   von/NNP
#   Mezburg/NNP
#   ./.)
